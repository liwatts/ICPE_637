# %% [markdown]
# ## Problem 1

# %% [markdown]
# ### 1.1
#
#  - Unsupervised Learning problem, since no classificiation is occurring, just trying to fill in the gap through looking at data points before and after the event
#
# ### 1.2
#
#  - y = Ae<sup>-kt</sup>cos($\omega t+\phi$)
#
#  - since this formula includes a growth/decay function to the cos wave
#
# ### 1.3
#
#  - For this problem, I think running an AR, MA, and ARMA model would be suitable for determining the best fit for the missing data. By plotting the autocorrelation and partial autocrrelation after running these models in python you would be able to determine whether the data is more representative of an AR MA or mixed.

# %% [markdown]
# ## Problem 2

# %% [markdown]
#  A -> 2 - adjusting the c<sub>1</sub> and c<sub>2</sub> constants helps create the elpsis shape that can separate the green and red region
#
#  B -> 3 - simple linear model where c<sub>1</sub> and c<sub>2</sub> adjust the slope of the line
#
#  C -> 1 - This function is a sine wave where c<sub>1</sub> controls the period of the wave
#
#  D -> 4 - This function is a sin wave as a function of both x and y allowing it to be on a diagonal axis

# %% [markdown]
# ## Bonus

# %% [markdown]
# With the parameters given for this problem, only 4 power plans are available to the customer.
#
# - The 1st plan by Frontier utilities is clearly the best option at a prie of 10.2 cents per kWh and a lower cancellation fee than the others at $150. All of these plans are based on a 3 month contract and supply 15% of your load from renewable sources.
#
# - The second plan by amigo energy prices in at 10.5 cents per kWh and is pretty identicle to the other 2 remaining plans. The only thing that sets it apart is it has a slightly higher company rating and conditional reasons why your rate might change
#
# - the third plan by just energy aslo charges 10.5 cents per kWh and has a cancellation fee of $175. They will not change your fixed rate of energy for the contract period thus also making it a good choice to consider.
#
# Holding all the priorities constant for this search, any other plans that exist either went over the 11 cents per kWh or failed to provide at least 15% of renewables. If my friend realized they would be consuming more than 500 kWh per month than other plans might meet the criteria.
